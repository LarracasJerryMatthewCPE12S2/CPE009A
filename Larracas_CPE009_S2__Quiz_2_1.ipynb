# %% [markdown]
# <a href="https://colab.research.google.com/github/LarracasJerryMatthewCPE12S2/CPE009A/blob/main/Larracas_CPE009_S2__Quiz_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We want to create a python code for a grading scheme

# Create a function to accept a number of activities
# Compute for the score vs total
# Return the average grade of the student in %
def termCrit(actNumber):
  rawScore = []
  totalScore = []

  for i in range(0, actNumber):
    inputScore = float(input("Score: "))
    inputTotal = float(input("Total: "))

    if inputScore > inputTotal:
      print("\nInvalid Scores.\n")
      inputScore, inputTotal = 0,0
      break
    else:
      rawScore.append(inputScore)
      totalScore.append(inputTotal)

  grade = sum(rawScore) / sum(totalScore)
  grade = grade * 100
  return grade

# %%
# Create a function for the class standing per term
def termCS():
  print("Hands-on Activities: ")
  termHOA = termCrit(int(input("How many hands-on activities this term?")))

  print("Quizzes:")
  termQuiz = termCrit(int(input("How many quizzes this term?")))

  print("Assignment: ")
  termAss = termCrit(int(input("How many assignments?")))

  grade = (0.5 * termHOA) + (0.3 * termQuiz) + (0.2 * termAss)
  return grade

# %%
# Create a function to compute the term grade
def termGrade():
  print("Computing for the term grade.")
  examRaw = float(input("Exam Score: "))
  examTotal = float(input("Exam Total: "))
  examGrade = (examRaw/examTotal) * 100

  CSgrade = termCS()

  grade = (0.5 * examGrade) + (0.5 * CSgrade)
  return grade

# %%
# Create a function to compute for the grades in the semester
def semesterGrade():
  print("Prelim Grade")
  prelimGrade = termGrade()

  print("Midterm Grade")
  midtermGrade = termGrade()
  finalMG = (1/3)*prelimGrade + (2/3)*midtermGrade

  print("Final Grade")
  finalGrade = termGrade()
  finalFG = (1/3)*finalMG + (2/3)*finalGrade

  return finalFG

# %%
def convertGrade(finalGrade):
  if finalGrade >= 94.0: return 1.0
  #The class should add everything else

# %%
# Driver Code

# Trial 1
print(convertGrade(semesterGrade()))

# Trial 2

# Trial 3
# Out:
# Prelim Grade
# Computing for the term grade.
# Exam Score: 1
# Exam Total: 1
# Hands-on Activities:
# How many hands-on activities this term?1
# Score: 1
# Total: 1
# Quizzes:
# How many quizzes this term?1
# Score: 1
# Total: 1
# Assignment:
# How many assignments?1
# Score: 1
# Total: 1
# Midterm Grade
# Computing for the term grade.
# Exam Score: 1
# Exam Total: 1
# Hands-on Activities:
# How many hands-on activities this term?1
# Score: 1
# Total: 1
# Quizzes:
# How many quizzes this term?1
# Score: 1
# Total: 1
# Assignment:
# How many assignments?1
# Score: 1
# Total: 1
# Final Grade
# Computing for the term grade.
# Exam Score: 1
# Exam Total: 1
# Hands-on Activities:
# How many hands-on activities this term?1
# Score: 1
# Total: 1
# Quizzes:
# How many quizzes this term?1
# Score: 1
# Total: 1
# Assignment:
# How many assignments?1
# Score: 1
# Total: 1
# 1.0

# %% [markdown]
# **What is the difference from the code you created?**
#
# There's a lot of difference from the code that I've modified, especially adding some loops and fixing the implementation of the function and lack of print syntax that's why the program does not run. But now I've fixed it, it is now working smoothly and fully functional.

# %%
# LARRACAS, JERRY MATTHEW L.                          Quiz 2.1
# CPE12S2 - CPE009
5
def termCrit(actNumber):
  rawScore = []
  totalScore = []

  for i in range(0, actNumber):
    while True:
      input_Score = float(input("Score:"))
      input_Total = float(input("Total Score:"))


      if input_Score > input_Total:
        print("\nInvalid Score, cannot be greater than total.\n")
      elif input_Total <= 0:
        print("\nInvalid Scores. re-enter\n")
      else:
        rawScore.append(input_Score)
        totalScore.append(input_Total)
        break
  if sum(totalScore) == 0:
    ave_grade = 0

  else:
    ave_grade = sum(rawScore) / sum(totalScore) * 100
    print("The average grade: ",ave_grade)
    return ave_grade



def termCS():
  print("\nHands-on Activities: ")
  termHOA = termCrit(int(input("How many hands-on activities this term? ")))

  print("Quizzes:")
  termQuiz = termCrit(int(input("How many quizzes this term? ")))

  print("Assignment: ")
  termAss = termCrit(int(input("How many assignments? ")))

  class_standing = (0.5 * termHOA) + (0.3 * termQuiz) + (0.2 * termAss)
  print("\nClass standing:",class_standing)
  return class_standing

def termGrade():
  print("\nComputing for the term grade.")
  while True:
    examRaw = float(input("Exam Score: "))
    examTotal = float(input("Exam Total: "))

    if examRaw > examTotal or examRaw <= 0 or examTotal <= 0:
     print("Invalid exam scores. Re-enter")
    else:
      break

  examGrade = (examRaw/examTotal) * 100
  print("\nExam grade: ",examGrade)

  CSgrade = termCS()

  grade = (0.5 * examGrade) + (0.5 * CSgrade)
  print("Prelim Grade: ",grade)
  return grade

def semesterGrade():
  print("--Prelim Grade--")
  prelimGrade = termGrade()

  print("\n--Midterm Grade--")
  midtermGrade = termGrade()
  finalMG = (1/3)*prelimGrade + (2/3)*midtermGrade

  print("\n--Final Grade--")
  finalGrade = termGrade()
  finalFG = (1/3)*finalMG + (2/3)*finalGrade

  print("\nSemester Final Grade:", finalFG)
  return finalFG

def convertGrade(finalGrade):
    if finalGrade >= 96.0:
        return 1.00, "PASSED"
    elif finalGrade >= 94.0:
        return 1.25, "PASSED"
    elif finalGrade >= 91.0:
        return 1.50, "PASSED"
    elif finalGrade >= 89.0:
        return 1.75, "PASSED"
    elif finalGrade >= 86.0:
        return 2.00, "PASSED"
    elif finalGrade >= 83.0:
        return 2.25, "PASSED"
    elif finalGrade >= 80.0:
        return 2.50, "PASSED"
    elif finalGrade >= 77.0:
        return 2.75, "PASSED"
    elif finalGrade >= 75.0:
        return 3.00, "PASSED"
    elif finalGrade >= 70.0:
        return 4.00, "PASSED"
    else:
        return 5.00, "FAILED"

finalGrade = semesterGrade()
remark = convertGrade(finalGrade)


print("Equivalent Grade:", remark)
# Out:
# --Prelim Grade--
#
# Computing for the term grade.
# Exam Score: 50
# Exam Total: 50
#
# Exam grade:  100.0
#
# Hands-on Activities:
# How many hands-on activities this term? 2
# Score:25
# Total Score:25
# Score:23
# Total Score:25
# The average grade:  96.0
# Quizzes:
# How many quizzes this term? 2
# Score:10
# Total Score:10
# Score:13
# Total Score:15
# The average grade:  92.0
# Assignment:
# How many assignments? 1
# Score:30
# Total Score:30
# The average grade:  100.0
#
# Class standing: 95.6
# Prelim Grade:  97.8
#
# --Midterm Grade--
#
# Computing for the term grade.
# Exam Score: 32
# Exam Total: 50
#
# Exam grade:  64.0
#
# Hands-on Activities:
# How many hands-on activities this term? 1
# Score:100
# Total Score:0
#
# Invalid Score, cannot be greater than total.
#
# Score:100
# Total Score:100
# The average grade:  100.0
# Quizzes:
# How many quizzes this term? 2
# Score:10
# Total Score:10
# Score:13
# Total Score:11
#
# Invalid Score, cannot be greater than total.
#
# Score:13
# Total Score:15
# The average grade:  92.0
# Assignment:
# How many assignments? 1
# Score:25
# Total Score:25
# The average grade:  100.0
#
# Class standing: 97.6
# Prelim Grade:  80.8
#
# --Final Grade--
#
# Computing for the term grade.
# Exam Score: 35
# Exam Total: 50
#
# Exam grade:  70.0
#
# Hands-on Activities:
# How many hands-on activities this term? 1
# Score:10
# Total Score:10
# The average grade:  100.0
# Quizzes:
# How many quizzes this term? 1
# Score:10
# Total Score:5
#
# Invalid Score, cannot be greater than total.
#
# Score:10
# Total Score:15
# The average grade:  66.66666666666666
# Assignment:
# How many assignments? 2
# Score:20
# Total Score:20
# Score:25
# Total Score:30
# The average grade:  90.0
#
# Class standing: 88.0
# Prelim Grade:  79.0
#
# Semester Final Grade: 81.48888888888888
# Equivalent Grade: (2.5, 'PASSED')
