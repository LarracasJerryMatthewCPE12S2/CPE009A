# %% [markdown]
# <a href="https://colab.research.google.com/github/LarracasJerryMatthewCPE12S2/CPE009A/blob/main/LarracasCpe12S2_HOA_3_1_Sequence_and_Mapping_Types_Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HOA 3.1 - Midterm

# %% [markdown]
# Name: Larracas, Jerry Matthew L.
#
# Section: CPE12S2
#
# Date performed: February 26, 2026

# %% [markdown]
# ## Contents
#  - [Procedures](#procedures)
#  - [Supplementary Activity](#supplementary_activities)
#  - [Conclusion](#conclusion)

# %% [markdown]
# ## Instructions for Lab Activities
# ---
# Document all procedures and supplementary tasks performed in the activity.
#
# You may use these links for reference on markdown with Jupyter:
#
# https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Notebook%20Basics.html
#
# https://colab.research.google.com/notebooks/welcome.ipynb
#
# https://colab.research.google.com/notebooks/markdown_guide.ipynb
#
# Be creative in documenting how you did the procedures below using the markdown. Also provide your observations as often as necessary per step.
#
# Place your code per **In [ ]** corresponding to the specified procedure. An example is given below

# %% [markdown]
# ## <a id="procedures">Procedures</a>

# %% [markdown]
# ### Lists

# %% [markdown]
# 1.	Create a variable numberlist and assign it the value of [5,4,2,1,3].

# %%
numberlist = [5,4,2,1,3]

# %% [markdown]
# 2. Print the following values below:

# %% [markdown]
# a.	len(numberlist)

# %%
len(numberlist)
# Out:
# 5

# %% [markdown]
# b.	numberlist[0]

# %%
print(numberlist[0])
# Out:
# 5

# %% [markdown]
# c.	numberlist[1]

# %%
print(numberlist[1])
# Out:
# 4

# %% [markdown]
# d.	numberlist[2]

# %%
print(numberlist[2])
# Out:
# 2

# %% [markdown]
# e.	numberlist[3]

# %%
print(numberlist[3])
# Out:
# 1

# %% [markdown]
# f.	numberlist[4]

# %%
print(numberlist[4])
# Out:
# 3

# %% [markdown]
# g.	numberlist[5]

# %%
print(numberlist[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-301/2892131904.py in <cell line: 0>()
# ----> 1 print(numberlist[5])
#
# IndexError: list index out of range

# %% [markdown]
# h.	numberlist[-1]

# %%
print(numberlist[-1])
# Out:
# 3

# %% [markdown]
# i.	numberlist[-2]

# %%
print(numberlist[-2])
# Out:
# 1

# %% [markdown]
# j.	numberlist[-3]

# %%
print(numberlist[-3])
# Out:
# 2

# %% [markdown]
# k.	numberlist[-4]

# %%
print(numberlist[-4])
# Out:
# 4

# %% [markdown]
# l.	numberlist[-5]

# %%
print(numberlist[-5])
# Out:
# 5

# %% [markdown]
# m.	numberlist[-6]

# %%
print(numberlist[-6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-301/1892020648.py in <cell line: 0>()
# ----> 1 print(numberlist[-6])
#
# IndexError: list index out of range

# %% [markdown]
# ### Observation:
# 3. Write your observation after printing all the values.
#
# Answer:  Base on my observation, printing all the values is the value that correspond on based on the assigned index

# %% [markdown]
# 4.	Create a variable named itemlist and assign it the value of [1,-2.0,[1,2,3],”Word”]

# %%
itemlist = [1, -2, 0,[1, 2, 3], "Word"]

# %% [markdown]
# 5.	Print the following values below:

# %% [markdown]
# a.	len(itemlist)

# %%
print(len(itemlist))

# %% [markdown]
# b.	itemlist [0]

# %%
print(itemlist [0])

# %% [markdown]
# c.	itemlist [1]

# %%
print(itemlist [1])

# %% [markdown]
# d.	itemlist [2]

# %%
print(itemlist [2])

# %% [markdown]
# e.	itemlist [3]

# %%
print(itemlist [3])

# %% [markdown]
# f.	len(itemlist[2])

# %%
print(len(itemlist[2]))

# %% [markdown]
# g.	itemlist [2][0]

# %%
print(itemlist [2][0])

# %% [markdown]
# h.	itemlist [2][1]

# %%
print(itemlist [2][1])

# %% [markdown]
# i.	itemlist [2][2]

# %%
print(itemlist [2][2])

# %% [markdown]
# j.	itemlist [-1]

# %%
print(itemlist [-1])

# %% [markdown]
# k.	itemlist [-2]

# %%
print(itemlist [-2])

# %% [markdown]
# l.	itemlist [-3]

# %%
print(itemlist [-3])

# %% [markdown]
# m.	itemlist [-4]

# %%
print(itemlist [-4])

# %% [markdown]
# n.	len(itemlist[-2])

# %%
print(len(itemlist[-2]))

# %% [markdown]
# o.	itemlist[-2][0]

# %%
print(itemlist[-2][0])

# %% [markdown]
# p.	itemlist[-2][1]

# %%
print(itemlist[-2][1])

# %% [markdown]
# q.	itemlist[-2][2]

# %%
print(itemlist[-2][2])

# %% [markdown]
# r.	itemlist[-2][-3]

# %%
print(itemlist[-2][-3])

# %% [markdown]
# s.	itemlist[-2][-2]

# %%
print(itemlist[-2][-2])

# %% [markdown]
# t.	itemlist[-2][-1]

# %%
print(itemlist[-2][-1)

# %% [markdown]
# ### Observation:
#
# 6. Write your observation after printing all the values. What does len() do?
#
# Answer: The len() function in Python is a built-in function that returns the number of items in an object.

# %% [markdown]
# # Index Slicing

# %% [markdown]
# 1. Create a new variable longlist and assign it the value of numberlist + itemlist.

# %%
numberlist = [5,4,2,1,3]; itemlist = [1, -2, 0,[1, 2, 3], "Word"]
longlist = numberlist + itemlist

# %% [markdown]
# 2. Print the following values below and write your observation for each of the following sub-groups (sub-headings):

# %% [markdown]
# a. len(longlist)

# %%
print(len(longlist))
# Out:
# 10

# %% [markdown]
# b. longlist [:]

# %%
print(longlist[:])
# Out:
# [5, 4, 2, 1, 3, 1, -2, 0, [1, 2, 3], 'Word']

# %% [markdown]
# c. longlist[:9]

# %%
print(longlist[:9])
# Out:
# [5, 4, 2, 1, 3, 1, -2, 0, [1, 2, 3]]

# %% [markdown]
# d. longlist[0:]

# %%
print(longlist[0:])
# Out:
# [5, 4, 2, 1, 3, 1, -2, 0, [1, 2, 3], 'Word']

# %% [markdown]
# e. longlist[1:]

# %%
print(longlist[1:])
# Out:
# [4, 2, 1, 3, 1, -2, 0, [1, 2, 3], 'Word']

# %% [markdown]
# f. longlist[2:]

# %%
print(longlist[2:])
# Out:
# [2, 1, 3, 1, -2, 0, [1, 2, 3], 'Word']

# %% [markdown]
# ## Index Slicing with Range

# %% [markdown]
# g. longlist[2:5]

# %%
print(longlist[2:5])
# Out:
# [2, 1, 3]

# %% [markdown]
# h. longlist[5:2]

# %%
print(longlist[5:2])
# Out:
# []

# %% [markdown]
# i. longlist[8:]

# %%
print(longlist[8:])
# Out:
# [[1, 2, 3], 'Word']

# %% [markdown]
# j. longlist[9:]

# %%
print(longlist[9:])
# Out:
# ['Word']

# %% [markdown]
# ## Index Slicing using Negative Indices

# %% [markdown]
# k. longlist[-9:]

# %%
print(longlist[-9:])
# Out:
# [4, 2, 1, 3, 1, -2, 0, [1, 2, 3], 'Word']

# %% [markdown]
# l. longlist[-8:]

# %%
print(longlist[-8:])
# Out:
# [2, 1, 3, 1, -2, 0, [1, 2, 3], 'Word']

# %% [markdown]
# m. longlist[-8:-7]

# %%
print(longlist[-8:-7])
# Out:
# [2]

# %% [markdown]
# n. longlist[-1:]

# %%
print(longlist[-1:])
# Out:
# ['Word']

# %% [markdown]
# ## Other properties of Index Slicing

# %% [markdown]
# o. longlist[10:20]

# %%
print(longlist[10:20])
# Out:
# []

# %% [markdown]
# p. longlist[-7:5]

# %%
print(longlist[-7:5])
# Out:
# [1, 3]

# %% [markdown]
# ## Index Slicing with Step parameter

# %% [markdown]
# q. longlist[::1]

# %%
print(longlist[::1])
# Out:
# [5, 4, 2, 1, 3, 1, -2, 0, [1, 2, 3], 'Word']

# %% [markdown]
# r. longlist[::2]

# %%
print(longlist[::2])
# Out:
# [5, 2, 3, -2, [1, 2, 3]]

# %% [markdown]
# s. longlist[1:8:2]

# %%
print(longlist[1:8:2])
# Out:
# [4, 1, 1, 0]

# %% [markdown]
# t. longlist[9:1:-1]

# %%
print(longlist[9:1:-1])
# Out:
# ['Word', [1, 2, 3], 0, -2, 1, 3, 1, 2]

# %% [markdown]
# u. longlist[-1::1]

# %%
print(longlist[-1::1])
# Out:
# ['Word']

# %% [markdown]
# v. longlist[-1::-1]

# %%
print(longlist[-1::-1])
# Out:
# ['Word', [1, 2, 3], 0, -2, 1, 3, 1, 2, 4, 5]

# %% [markdown]
# ## Observation:
#
# 3. Write your main observation about index slicing as a whole.
#
# Answer: The index slicing has a main format and that is start, end, step. The start index is inclusive, meaning the element at that position is part of the result. The end index is exclusive.

# %% [markdown]
# # List Methods and the Mutable Property of Lists

# %% [markdown]
# 1. Create a new variable numberlist2 and assign it to be equal to numberlist.

# %%
numberlist2 = numberlist

# %% [markdown]
# 2. Print the value of numberlist.

# %%
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 3. Print the value of numberlist2.

# %%
print(numberlist2)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 4. Assign the value of numberlist[0] to be equal to 6.

# %%
(numberlist[0]) = 6

# %% [markdown]
# 5. Print the value of numberlist.

# %%
print(numberlist)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# 6. Print the value of numberlist2.

# %%
print(numberlist2)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# 7. Observe how numberlist2 is affected by changes in numberlist due to the
# assignment.
#
# Answer: numberlist2 being affected by the changes in numberlist due because we assigned the numberlist 2 is equal to the numberlist, that's why when we change the values in numberlist, numberlist 2 is also affected.

# %% [markdown]
# 8. Change the value of numberlist2 and assign it the value of numberlist.copy()

# %%
numberlist2 = numberlist.copy()

# %% [markdown]
# 9. Print the value of numberlist2

# %%
print(numberlist2)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# 10. Assign the value of numberlist[0] to be equal to 5.

# %%
numberlist[0] = 5

# %% [markdown]
# 11. Print the value of numberlist.

# %%
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 12. Print the value of numberlist2.

# %%
print(numberlist2)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# # Observation:
# 13. Write your observation about the immutable property and the difference of assigning numberlist2 to be equal to numberlist and the numberlist.copy() method.
#
# Answer: Actually what i see is both method are the same, assigning to be equal is fasther though, numberlist.copy method has more formal look.

# %% [markdown]
# # Exploring some List Functions and Methods

# %% [markdown]
# 1. Print the value of numberlist

# %%
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 2. Run the command numberlist.append(6)

# %%
numberlist.append(6)

# %% [markdown]
# 3. Print the value of numberlist

# %%
print(numberlist)
# Out:
# [5, 4, 2, 1, 3, 6]

# %% [markdown]
# 4. Run the command numberlist.pop()

# %%
numberlist.pop()
# Out:
# 6

# %% [markdown]
# 5. Print the value of numberlist

# %%
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %% [markdown]
# 6. Run the command numberlist.sort()

# %%
numberlist.sort()

# %% [markdown]
# 7. Print the value of numberlist

# %%
print(numberlist)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 8. Run the command itemlist.sort()

# %%
itemlist.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_163/1809657090.py in <cell line: 0>()
# ----> 1 itemlist.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %% [markdown]
# 9. Print the values: min(numberlist) and max(numberlist)

# %%
print(min(numberlist))
print(max(numberlist))
# Out:
# 1
# 5

# %% [markdown]
# 10. Print the value of longlist

# %%
print(longlist)
# Out:
# [5, 4, 2, 1, 3, 1, -2, 0, [1, 2, 3], 'Word']

# %% [markdown]
# 11. Print the value of longlist.count(1)

# %%
print(longlist.count(1))
# Out:
# 2

# %% [markdown]
# 12. Print the value of longlist[7].count(1)

# %%
print(longlist[7].count(1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_163/200783462.py in <cell line: 0>()
# ----> 1 print(longlist[7].count(1))
#
# AttributeError: 'int' object has no attribute 'count'

# %% [markdown]
# # The in operator

# %% [markdown]
# 1. Type the code as shown: print(3 in longlist)

# %%
print(3 in longlist)
# Out:
# True

# %% [markdown]
# 2. Type the code as shown: print(15 in longlist)

# %%
print(15 in longlist)
# Out:
# False

# %% [markdown]
# 3. Type the code as shown below:
#
#  num = int(input(“Enter a number: ”)) if num in longlist:
#
# print(“The number is in longlist”)
#
# else:
# print(“The number is not in longlist”)

# %%
num = int(input("Enter a number: "))
if num in longlist:
  print("The number is in longlist")
else :
  print("The number is not in longlist")
# Out:
# Enter a number: 5
# The number is in longlist

# %% [markdown]
# # Observation:
#
# 4. Write your observations on the in operator.

# %% [markdown]
# # Using a list in an iterative statement

# %% [markdown]
# 1. Type the code as shown below: for item in longlist:
#
# print(item)

# %%
for item in longlist:
  print(item)
# Out:
# 5
# 4
# 2
# 1
# 3
# 1
# -2
# 0
# [1, 2, 3]
# Word

# %% [markdown]
# 2. Type the code as shown below:
#
# i=0 while i<len(longlist): print(longlist[i]) i+=1

# %%
i = 0
while i < len(longlist):
  print(longlist[i])
  i += 1
# Out:
# 5
# 4
# 2
# 1
# 3
# 1
# -2
# 0
# [1, 2, 3]
# Word

# %% [markdown]
# # Strings
# 1. Create a variable named message and assign it the value of “Hello World”

# %%
message = "Hello world"

# %% [markdown]
# 2. Print the value of message

# %%
print(message)
# Out:
# Hello world

# %% [markdown]
# 3. Print the value: len(message)

# %%
print(len(message))
# Out:
# 11

# %% [markdown]
# 4. Apply the concept of index values in the List section and individually display the characters “H”, “E”, “L”, “L”, “O”
# using the print() function. Note: Try using positive indexes, then after seeing the result. Repeat the step using negative indexes.

# %%
print(message[0].upper())
print(message[1].upper())
print(message[2].upper())
print(message[2].upper())
print(message[4].upper())
# Out:
# H
# E
# L
# L
# O

# %% [markdown]
# 5. Apply the concept of index values in the List section and display the string “Hold” using the Concatenate (+) operator on individual characters.
# Ex. print(message[0]+ message[1]+ message[2]+ message[3]+ message[4])

# %%
print(message[0] + message[4] + message[2] + message[10])
# Out:
# Hold

# %% [markdown]
# 6. Apply the concept of index slicing in the Index Slicing section and display the word “Hello” as a whole string.

# %%
print(message[0:5])
# Out:
# Hello

# %% [markdown]
# 7. Apply the concept of index slicing in the Index Slicing section and display the word “World” as a whole string.

# %%
print(message[6:11])
# Out:
# world

# %% [markdown]
# # String Methods

# %% [markdown]
# 1. Type the command and print the value message.upper() Ex. print(message.upper())

# %%
print(message.upper())
# Out:
# HELLO WORLD

# %% [markdown]
# 2. Type the command and print the value	message.lower()

# %%
print(message.lower())
# Out:
# hello world

# %% [markdown]
# 3. Type the command and print the value	message.title()

# %%
print(message.title())
# Out:
# Hello World

# %% [markdown]
# 4. Print the value “Value 1 is {}, and value 2 is {}”.format(-1,True)

# %%
print("Value 1 is {}, and value 2 is {}".format(-1,True))
# Out:
# Value 1 is -1, and value 2 is True

# %% [markdown]
# 5. Print the value message.split(' ')

# %%
print(message.split(' '))
# Out:
# ['Hello', 'world']

# %% [markdown]
# 6. Print the value message.count(‘l’)

# %%
print(message.count('l'))
# Out:
# 3

# %% [markdown]
# 7. Print the value message.replace(‘World’, ‘CPE009’)

# %%
print(message.replace('world','CPE009'))
# Out:
# Hello CPE009

# %% [markdown]
# 8. Assign the value message.replace(‘World’,‘CPE009’) to message

# %%
message = message.replace("world", "CPE009")
print(message)
# Out:
# Hello CPE009

# %% [markdown]
# 9. Type the command: help(“”)
#
# Find the commands used in previous tasks.

# %%
help("")
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(...)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rmod__(self, value, /)
#  |      Return value%self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __sizeof__(self, /)
#  |      Return the size of the string in memory, in bytes.
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  capitalize(self, /)
#  |      Return a capitalized version of the string.
#  |
#  |      More specifically, make the first character have upper case and the rest lower
#  |      case.
#  |
#  |  casefold(self, /)
#  |      Return a version of the string suitable for caseless comparisons.
#  |
#  |  center(self, width, fillchar=' ', /)
#  |      Return a centered string of length width.
#  |
#  |      Padding is done using the specified fill character (default is a space).
#  |
#  |  count(...)
#  |      S.count(sub[, start[, end]]) -> int
#  |
#  |      Return the number of non-overlapping occurrences of substring sub in
#  |      string S[start:end].  Optional arguments start and end are
#  |      interpreted as in slice notation.
#  |
#  |  encode(self, /, encoding='utf-8', errors='strict')
#  |      Encode the string using the codec registered for encoding.
#  |
#  |      encoding
#  |        The encoding in which to encode the string.
#  |      errors
#  |        The error handling scheme to use for encoding errors.
#  |        The default is 'strict' meaning that encoding errors raise a
#  |        UnicodeEncodeError.  Other possible values are 'ignore', 'replace' and
#  |        'xmlcharrefreplace' as well as any other name registered with
#  |        codecs.register_error that can handle UnicodeEncodeErrors.
#  |
#  |  endswith(...)
#  |      S.endswith(suffix[, start[, end]]) -> bool
#  |
#  |      Return True if S ends with the specified suffix, False otherwise.
#  |      With optional start, test S beginning at that position.
#  |      With optional end, stop comparing S at that position.
#  |      suffix can also be a tuple of strings to try.
#  |
#  |  expandtabs(self, /, tabsize=8)
#  |      Return a copy where all tab characters are expanded using spaces.
#  |
#  |      If tabsize is not given, a tab size of 8 characters is assumed.
#  |
#  |  find(...)
#  |      S.find(sub[, start[, end]]) -> int
#  |
#  |      Return the lowest index in S where substring sub is found,
#  |      such that sub is contained within S[start:end].  Optional
#  |      arguments start and end are interpreted as in slice notation.
#  |
#  |      Return -1 on failure.
#  |
#  |  format(...)
#  |      S.format(*args, **kwargs) -> str
#  |
#  |      Return a formatted version of S, using substitutions from args and kwargs.
#  |      The substitutions are identified by braces ('{' and '}').
#  |
#  |  format_map(...)
#  |      S.format_map(mapping) -> str
#  |
#  |      Return a formatted version of S, using substitutions from mapping.
#  |      The substitutions are identified by braces ('{' and '}').
#  |
#  |  index(...)
#  |      S.index(sub[, start[, end]]) -> int
#  |
#  |      Return the lowest index in S where substring sub is found,
#  |      such that sub is contained within S[start:end].  Optional
#  |      arguments start and end are interpreted as in slice notation.
#  |
#  |      Raises ValueError when the substring is not found.
#  |
#  |  isalnum(self, /)
#  |      Return True if the string is an alpha-numeric string, False otherwise.
#  |
#  |      A string is alpha-numeric if all characters in the string are alpha-numeric and
#  |      there is at least one character in the string.
#  |
#  |  isalpha(self, /)
#  |      Return True if the string is an alphabetic string, False otherwise.
#  |
#  |      A string is alphabetic if all characters in the string are alphabetic and there
#  |      is at least one character in the string.
#  |
#  |  isascii(self, /)
#  |      Return True if all characters in the string are ASCII, False otherwise.
#  |
#  |      ASCII characters have code points in the range U+0000-U+007F.
#  |      Empty string is ASCII too.
#  |
#  |  isdecimal(self, /)
#  |      Return True if the string is a decimal string, False otherwise.
#  |
#  |      A string is a decimal string if all characters in the string are decimal and
#  |      there is at least one character in the string.
#  |
#  |  isdigit(self, /)
#  |      Return True if the string is a digit string, False otherwise.
#  |
#  |      A string is a digit string if all characters in the string are digits and there
#  |      is at least one character in the string.
#  |
#  |  isidentifier(self, /)
#  |      Return True if the string is a valid Python identifier, False otherwise.
#  |
#  |      Call keyword.iskeyword(s) to test whether string s is a reserved identifier,
#  |      such as "def" or "class".
#  |
#  |  islower(self, /)
#  |      Return True if the string is a lowercase string, False otherwise.
#  |
#  |      A string is lowercase if all cased characters in the string are lowercase and
#  |      there is at least one cased character in the string.
#  |
#  |  isnumeric(self, /)
#  |      Return True if the string is a numeric string, False otherwise.
#  |
#  |      A string is numeric if all characters in the string are numeric and there is at
#  |      least one character in the string.
#  |
#  |  isprintable(self, /)
#  |      Return True if all characters in the string are printable, False otherwise.
#  |
#  |      A character is printable if repr() may use it in its output.
#  |
#  |  isspace(self, /)
#  |      Return True if the string is a whitespace string, False otherwise.
#  |
#  |      A string is whitespace if all characters in the string are whitespace and there
#  |      is at least one character in the string.
#  |
#  |  istitle(self, /)
#  |      Return True if the string is a title-cased string, False otherwise.
#  |
#  |      In a title-cased string, upper- and title-case characters may only
#  |      follow uncased characters and lowercase characters only cased ones.
#  |
#  |  isupper(self, /)
#  |      Return True if the string is an uppercase string, False otherwise.
#  |
#  |      A string is uppercase if all cased characters in the string are uppercase and
#  |      there is at least one cased character in the string.
#  |
#  |  join(self, iterable, /)
#  |      Concatenate any number of strings.
#  |
#  |      The string whose method is called is inserted in between each given string.
#  |      The result is returned as a new string.
#  |
#  |      Example: '.'.join(['ab', 'pq', 'rs']) -> 'ab.pq.rs'
#  |
#  |  ljust(self, width, fillchar=' ', /)
#  |      Return a left-justified string of length width.
#  |
#  |      Padding is done using the specified fill character (default is a space).
#  |
#  |  lower(self, /)
#  |      Return a copy of the string converted to lowercase.
#  |
#  |  lstrip(self, chars=None, /)
#  |      Return a copy of the string with leading whitespace removed.
#  |
#  |      If chars is given and not None, remove characters in chars instead.
#  |
#  |  partition(self, sep, /)
#  |      Partition the string into three parts using the given separator.
#  |
#  |      This will search for the separator in the string.  If the separator is found,
#  |      returns a 3-tuple containing the part before the separator, the separator
#  |      itself, and the part after it.
#  |
#  |      If the separator is not found, returns a 3-tuple containing the original string
#  |      and two empty strings.
#  |
#  |  removeprefix(self, prefix, /)
#  |      Return a str with the given prefix string removed if present.
#  |
#  |      If the string starts with the prefix string, return string[len(prefix):].
#  |      Otherwise, return a copy of the original string.
#  |
#  |  removesuffix(self, suffix, /)
#  |      Return a str with the given suffix string removed if present.
#  |
#  |      If the string ends with the suffix string and that suffix is not empty,
#  |      return string[:-len(suffix)]. Otherwise, return a copy of the original
#  |      string.
#  |
#  |  replace(self, old, new, count=-1, /)
#  |      Return a copy with all occurrences of substring old replaced by new.
#  |
#  |        count
#  |          Maximum number of occurrences to replace.
#  |          -1 (the default value) means replace all occurrences.
#  |
#  |      If the optional argument count is given, only the first count occurrences are
#  |      replaced.
#  |
#  |  rfind(...)
#  |      S.rfind(sub[, start[, end]]) -> int
#  |
#  |      Return the highest index in S where substring sub is found,
#  |      such that sub is contained within S[start:end].  Optional
#  |      arguments start and end are interpreted as in slice notation.
#  |
#  |      Return -1 on failure.
#  |
#  |  rindex(...)
#  |      S.rindex(sub[, start[, end]]) -> int
#  |
#  |      Return the highest index in S where substring sub is found,
#  |      such that sub is contained within S[start:end].  Optional
#  |      arguments start and end are interpreted as in slice notation.
#  |
#  |      Raises ValueError when the substring is not found.
#  |
#  |  rjust(self, width, fillchar=' ', /)
#  |      Return a right-justified string of length width.
#  |
#  |      Padding is done using the specified fill character (default is a space).
#  |
#  |  rpartition(self, sep, /)
#  |      Partition the string into three parts using the given separator.
#  |
#  |      This will search for the separator in the string, starting at the end. If
#  |      the separator is found, returns a 3-tuple containing the part before the
#  |      separator, the separator itself, and the part after it.
#  |
#  |      If the separator is not found, returns a 3-tuple containing two empty strings
#  |      and the original string.
#  |
#  |  rsplit(self, /, sep=None, maxsplit=-1)
#  |      Return a list of the substrings in the string, using sep as the separator string.
#  |
#  |        sep
#  |          The separator used to split the string.
#  |
#  |          When set to None (the default value), will split on any whitespace
#  |          character (including \n \r \t \f and spaces) and will discard
#  |          empty strings from the result.
#  |        maxsplit
#  |          Maximum number of splits.
#  |          -1 (the default value) means no limit.
#  |
#  |      Splitting starts at the end of the string and works to the front.
#  |
#  |  rstrip(self, chars=None, /)
#  |      Return a copy of the string with trailing whitespace removed.
#  |
#  |      If chars is given and not None, remove characters in chars instead.
#  |
#  |  split(self, /, sep=None, maxsplit=-1)
#  |      Return a list of the substrings in the string, using sep as the separator string.
#  |
#  |        sep
#  |          The separator used to split the string.
#  |
#  |          When set to None (the default value), will split on any whitespace
#  |          character (including \n \r \t \f and spaces) and will discard
#  |          empty strings from the result.
#  |        maxsplit
#  |          Maximum number of splits.
#  |          -1 (the default value) means no limit.
#  |
#  |      Splitting starts at the front of the string and works to the end.
#  |
#  |      Note, str.split() is mainly useful for data that has been intentionally
#  |      delimited.  With natural text that includes punctuation, consider using
#  |      the regular expression module.
#  |
#  |  splitlines(self, /, keepends=False)
#  |      Return a list of the lines in the string, breaking at line boundaries.
#  |
#  |      Line breaks are not included in the resulting list unless keepends is given and
#  |      true.
#  |
#  |  startswith(...)
#  |      S.startswith(prefix[, start[, end]]) -> bool
#  |
#  |      Return True if S starts with the specified prefix, False otherwise.
#  |      With optional start, test S beginning at that position.
#  |      With optional end, stop comparing S at that position.
#  |      prefix can also be a tuple of strings to try.
#  |
#  |  strip(self, chars=None, /)
#  |      Return a copy of the string with leading and trailing whitespace removed.
#  |
#  |      If chars is given and not None, remove characters in chars instead.
#  |
#  |  swapcase(self, /)
#  |      Convert uppercase characters to lowercase and lowercase characters to uppercase.
#  |
#  |  title(self, /)
#  |      Return a version of the string where each word is titlecased.
#  |
#  |      More specifically, words start with uppercased characters and all remaining
#  |      cased characters have lower case.
#  |
#  |  translate(self, table, /)
#  |      Replace each character in the string using the given translation table.
#  |
#  |        table
#  |          Translation table, which must be a mapping of Unicode ordinals to
#  |          Unicode ordinals, strings, or None.
#  |
#  |      The table must implement lookup/indexing via __getitem__, for instance a
#  |      dictionary or list.  If this operation raises LookupError, the character is
#  |      left untouched.  Characters mapped to None are deleted.
#  |
#  |  upper(self, /)
#  |      Return a copy of the string converted to uppercase.
#  |
#  |  zfill(self, width, /)
#  |      Pad a numeric string with zeros on the left, to fill a field of the given width.
#  |
#  |      The string is never truncated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  maketrans(...)
#  |      Return a translation table usable for str.translate().
#  |
#  |      If there is only one argument, it must be a dictionary mapping Unicode
#  |      ordinals (integers) or characters to Unicode ordinals, strings or None.
#  |      Character keys will be then converted to ordinals.
#  |      If there are two arguments, they must be strings of equal length, and
#  |      in the resulting dictionary, each character in x will be mapped to the
#  |      character at the same position in y. If there is a third argument, it
#  |      must be a string, whose characters will be mapped to None in the result.

# %% [markdown]
# # The in operator for Strings
#
# 1. Type the code as shown: print(‘W’ in message)

# %%
print('w' in message)
# Out:
# False

# %% [markdown]
# 2. Type the code as shown: print(‘old’ in message)

# %%
print('old' in message)
# Out:
# False

# %% [markdown]
# 3. Type the codes below:
#
# word = input(“Enter a word: ”)
# if word in “The big brown fox jump over the lazy dog”:
#
# print(“The word is in the text”)
#
# else:
# print(“The word is not in the text”)

# %%
word = input("Enter a word: ")
if word in "The big brown fox jump over the lazy dog":
  print("The word is in the text")
else:
  print("The word is not in the text")
# Out:
# Enter a word: fox
# The word is in the text

# %% [markdown]
# # Using a String in an iterative statement
# 1. Type the code as shown below: for character in message:
# print(character)

# %%
for character in message:
  print(character)
# Out:
# H
# e
# l
# l
# o
#
# C
# P
# E
# 0
# 0
# 9

# %% [markdown]
# 2. Type the code as shown below: i = 0
# while i<len(message): print(message[i]) i+=1

# %%
i = 0
while i < len(message):
  print(message[i])
  i += 1
# Out:
# H
# e
# l
# l
# o
#
# C
# P
# E
# 0
# 0
# 9

# %% [markdown]
# # Tuples
# 1. Create a variable named tuplelist and assign the value of (1,2,3,4,5)

# %%
tuplelist = [1, 2, 3, 4, 5]

# %% [markdown]
# 2. Print the following values:
#
# a. numberlist[0]

# %%
print(numberlist[0])
# Out:
# 1

# %% [markdown]
# b. numberlist[1]

# %%
print(numberlist[1])
# Out:
# 2

# %% [markdown]
# c. numberlist[2]

# %%
print(numberlist[2])
# Out:
# 3

# %% [markdown]
# d. numberlist[3]

# %%
print(numberlist[3])
# Out:
# 4

# %% [markdown]
# e. numberlist[4]

# %%
print(numberlist[4])
# Out:
# 5

# %% [markdown]
# f. numberlist[5]

# %%
print(numberlist[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_163/2892131904.py in <cell line: 0>()
# ----> 1 print(numberlist[5])
#
# IndexError: list index out of range

# %% [markdown]
# 3. Print the output of tuplelist + (1,2,3)

# %%
print(tuplelist + [1, 2, 3])
# Out:
# [1, 2, 3, 4, 5, 1, 2, 3]

# %% [markdown]
# 4. Assign tuplelist[0] = 15

# %%
tuplelist[0] = 15

# %% [markdown]
# 5. Observe the output.
#
# Answer: The output will print 15

# %% [markdown]
# 6. Try string slicing through the elements of tuplelist as in numberlist and message.

# %%
print(tuplelist[0:3])
print(tuplelist[2:])
print(tuplelist[-2:])
# Out:
# [15, 2, 3]
# [3, 4, 5]
# [4, 5]

# %% [markdown]
# 7. Create a for loop that would print the numbers inside the tuple.

# %%
for num in tuplelist:
    print(num)
# Out:
# 15
# 2
# 3
# 4
# 5

# %% [markdown]
# # Dictionaries
# 1. Create a dictionary named
# contactinfo = {‘id’:1, ’first_name’:’John’, ’last_name’:’Doe’, ’contact_number’:’09060611233’}

# %%
contactinfo = {'id': 1, 'first_name': 'John', 'last_name': 'Doe', 'contact_number': '09060611233'}

# %% [markdown]
# 2. Print the following values:
#
# a. contactinfo[‘id’]

# %%
print(contactinfo['id'])
# Out:
# 1

# %% [markdown]
# b. contactinfo[‘first_name’]

# %%
print(contactinfo['first_name'])
# Out:
# John

# %% [markdown]
# c. contactinfo[‘last_name’]

# %%
print(contactinfo['last_name'])
# Out:
# Doe

# %% [markdown]
# d. contactinfo[‘contact_number’]

# %%
print(contactinfo['contact_number'])
# Out:
# 09060611233

# %% [markdown]
# e. contactinfo[‘age’]

# %%
print(contactinfo['age'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_163/884092210.py in <cell line: 0>()
# ----> 1 print(contactinfo['age'])
#
# KeyError: 'age'

# %% [markdown]
# 3. Type the code:
# for k,v in contactinfo: print(k)

# %%
for k, v in contactinfo.items():
  print(k)
# Out:
# id
# first_name
# last_name
# contact_number

# %% [markdown]
# 4. Type the code:
# for k,v in contactinfo.items(): print(k,v)

# %%
for k, v in contactinfo.items():
  print(k, v)
# Out:
# id 1
# first_name John
# last_name Doe
# contact_number 09060611233

# %% [markdown]
# 5. Assign the values:
#
# a. contactinfo[‘id’] = 2

# %%
contactinfo['id'] = 2

# %% [markdown]
# b. contactinfo[‘first_name’] = ‘Max’

# %%
contactinfo['first_name'] = 'Max'

# %% [markdown]
# 6. Print contactinfo

# %%
print(contactinfo)
# Out:
# {'id': 2, 'first_name': 'Max', 'last_name': 'Doe', 'contact_number': '09060611233'}

# %% [markdown]
# ## <a id="supplementary_activities">Supplementary Activity</a>

# %% [markdown]
# # Tasks
# Distance Formula
# 1. Make a program that would calculate the distance between two points given a list of coordinates. Use the distance formula.
# coorindates_list = [(1,1), (2,3)]

# %%
import math


coordinates_list = [(1, 1), (2, 3)]

x1, y1 = coordinates_list[0]
x2, y2 = coordinates_list[1]

distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

print("Distance between points:", distance)
# Out:
# Distance between points: 2.23606797749979

# %% [markdown]
# Simple Word Filter
#
# 2. For a given string input, replace all the words “stupid” with an asterisk * equal to the length of the string. The new
# string value should be displayed with the asterisks.

# %%
text = "That was a stupid idea, such a stupid mistake."
filtered_text = text.replace("stupid", "*" * len("stupid"))
print("Filtered text:", filtered_text)
# Out:
# Filtered text: That was a ****** idea, such a ****** mistake.

# %% [markdown]
# Phonebook
#
# 3. Create a simple phonebook program that can read from a list of dictionaries. The program should be able to display a
# person’s name, contact, and address based from a user input which is the id of the record.

# %%
phonebook = [
    {"id": 1, "name": "Roy", "contact": "09123456789", "address": "Quezon City"},
    {"id": 2, "name": "Bien", "contact": "09987654321", "address": "Manila"},
    {"id": 3, "name": "Twain", "contact": "09876543210", "address": "Cebu"}
]


user_id = int(input("Enter the ID of the person: "))

found = False
for record in phonebook:
    if record["id"] == user_id:
        print("Name:", record["name"])
        print("Contact:", record["contact"])
        print("Address:", record["address"])
        found = True
        break

if not found:
    print("Record not found.")
# Out:
# Enter the ID of the person: 1
# Name: Roy
# Contact: 09123456789
# Address: Quezon City

# %% [markdown]
# ## <a id="conclusion">Conclusion</a>
#
# In conlusion, I was able to learn so much in this lesson. I was able to learn about len(), indexing, slicing, Concatenation, and replace() syntaxes. It is easy to understand and not that complicated to use. It helped me to be more advanced and gain more knowledge about python. Furthermore, This functions made my work ligthier and faster to do now.
