# %% [markdown]
# <a href="https://colab.research.google.com/github/LarracasJerryMatthewCPE12S2/CPE009A/blob/main/Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Larracas, Jerry Matthew L.
#
# > CPE009A - CPE12S2

# %%
# no.23 question Midterm Exam
i = 1
for a in range(5):
  for a in range(1+a):
    print("*", end="")
  print()

for a in range(5):
  for a in range(5-a):
    print("*", end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****
# *****
# ****
# ***
# **
# *

# %%
checking = '({[]})'
print(input())

if checking == "({[]})":
  print("True")
else:
  print("False")
# Out:
# ()
# ()
# True
